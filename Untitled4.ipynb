# %%
import numpy as np
import math
import scipy
import pandas as pd

# %%
data= np.array([5,10,15,10,20])

# %%
df=pd.DataFrame(data)

# %%
mean=df.mean()

# %%
df.median()
# Out:
# 0    10.0
# dtype: float64

# %%
df.describe()
# Out:
#                0
# count   5.000000
# mean   12.000000
# std     5.700877
# min     5.000000
# 25%    10.000000
# 50%    10.000000
# 75%    15.000000
# max    20.000000

# %%
df.isnull()
# Out:
#        0
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
df.sum()
# Out:
# 0    60
# dtype: int64

# %% [markdown]
# #Total Sum OF Square

# %%
sum=0
for i in df:
   sum +=np.sum((data[i]-mean) ** 2)

# %%
sum
# Out:
# 49.0

# %% [markdown]
# ##Question 2

# %%
# data1 = np.array([30, 10, 70, 40, 80])

# %%
number =[]
for i in range (5):
    num=int(input("Enter the number:"))
    number.append(num)
    t_sum=sum(number)
    avg=t_sum/len(number)
    print("Sum",t_sum)
    print("Avg:",avg)
# Out:
# Enter the number: 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[169], line 5
#       3 num=int(input("Enter the number:"))
#       4 number.append(num)
# ----> 5 t_sum=sum(number)
#       6 avg=t_sum/len(number)
#       7 print("Sum",t_sum)
#
# TypeError: 'numpy.float64' object is not callable

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 Totalsum=Sum(number)
#
# NameError: name 'Sum' is not defined
